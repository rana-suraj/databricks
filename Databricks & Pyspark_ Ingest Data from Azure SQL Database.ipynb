# %%
jdbc_url = (
    "jdbc:sqlserver://takeodemo.database.windows.net:1433;"
    "database=takeo;"
    "encrypt=true;"
    "trustServerCertificate=false;"
    "loginTimeout=30;"
)

# %%
connection_properties = {
    "user": "test",
    "password": "pass@1234",
    "driver": "com.microsoft.sqlserver.jdbc.SQLServerDriver"
}

df = spark.read.jdbc(
    url=jdbc_url,
    table="employees",
    properties=connection_properties
)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
